# %%
# Plot Selection
from plotting import TestPlotter
plotter = TestPlotter()
plotter.display()

# %%
# Data Table Selection
from plotting import TestSelector

selector = TestSelector()
selector.display()

# %%
# Data Table Printing and Analysis - Starts with comparison of regression test data
from plotting import RegressionCompare
rc = RegressionCompare(selector.get_path())
original, obtained = rc.get_comparables()

comparison = original.compare(obtained, result_names=("orig", "obt"), keep_equal=False, keep_shape=True, align_axis=1)
comparison
